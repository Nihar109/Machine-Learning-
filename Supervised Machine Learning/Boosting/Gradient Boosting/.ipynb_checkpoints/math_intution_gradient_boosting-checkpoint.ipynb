# %%
import pandas as pd

# %%
# df = pd.DataFrame({'R&D Spend' :[165.0,101.0,29.0],'Administration':[137.0,92.0,127.0],'Marketing Spend':[472.0,250.0,201.0],'profit':[192.0,144.0,91.0]})
# df

# %%
df = pd.read_csv('50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.drop(['State'],axis=1,inplace=True)
df
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# ...

# %%
# df = df.sample(3)
df = df.loc[[0,11,36]]
df
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 11  100671.96        91790.61        249744.55  144259.40
# 36   28663.76       127056.21        201126.82   90708.19

# %%
df = round(df/1000)
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit
# 0       165.0           137.0            472.0   192.0
# 11      101.0            92.0            250.0   144.0
# 36       29.0           127.0            201.0    91.0

# %%
# step-1
df['f0(x)'] = df.Profit.mean()
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit       f0(x)
# 0       165.0           137.0            472.0   192.0  142.333333
# 11      101.0            92.0            250.0   144.0  142.333333
# 36       29.0           127.0            201.0    91.0  142.333333

# %%
# step-2.a
df['ri1'] = df['Profit'] - df['f0(x)']
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit       f0(x)        ri1
# 0       165.0           137.0            472.0   192.0  142.333333  49.666667
# 11      101.0            92.0            250.0   144.0  142.333333   1.666667
# 36       29.0           127.0            201.0    91.0  142.333333 -51.333333

# %%
# step 2.b
from sklearn.tree import DecisionTreeRegressor
dt1 = DecisionTreeRegressor(max_depth=1) # only 3 no of dataset
dt1.fit(df.iloc[:,:3].values,df.ri1.values)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
from sklearn.tree import plot_tree
plot_tree(dt1)
# Out:
# [Text(0.5, 0.75, 'X[0] <= 65.0\nsquared_error = 1701.556\nsamples = 3\nvalue = -0.0'),
#  Text(0.25, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = -51.333'),
#  Text(0.75, 0.25, 'squared_error = 576.0\nsamples = 2\nvalue = 25.667')]

# %%
df['f1(x)'] = dt1.predict(df.iloc[:,:3].values)
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit       f0(x)        ri1  \
# 0       165.0           137.0            472.0   192.0  142.333333  49.666667
# 11      101.0            92.0            250.0   144.0  142.333333   1.666667
# 36       29.0           127.0            201.0    91.0  142.333333 -51.333333
#
#         f1(x)
# 0   25.666667
# 11  25.666667
# 36 -51.333333

# %%
df['predict1'] = df['f0(x)'] + df['f1(x)']
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit       f0(x)        ri1  \
# 0       165.0           137.0            472.0   192.0  142.333333  49.666667
# 11      101.0            92.0            250.0   144.0  142.333333   1.666667
# 36       29.0           127.0            201.0    91.0  142.333333 -51.333333
#
#         f1(x)  predict1
# 0   25.666667     168.0
# 11  25.666667     168.0
# 36 -51.333333      91.0

# %%
def gradient_boost(X,y,number,lr,count=1,regs=[],foo=None):
    
    if number == 0:
        return
    else:
        # do gradient boosting
        
        if count> 1:
            y = y - regs[-1].predict(X)
        else:
            foo = y
        dt1 = DecisionTreeRegressor(max_leaf_nodes=8)
        dt1.fit(X,y)
        
        regs.append(dt1)
        
        y_pred = y.mean() + lr * sum(dt.predict(x1.reshape(-1,1)) for dt in regs)

        gradient_boost(X,y,number-1,lr,count+1,regs,foo=foo)
