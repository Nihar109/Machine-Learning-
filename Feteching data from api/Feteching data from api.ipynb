# %% [markdown]
# id
# titile
# release date
# overview
# popularity
# vote_avg
# vote_count
#
# 10291 * 5

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=61e0011ba95dcb6e15587b2ebe4fd456&language=en-US&page=1')

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 106.84,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 16544},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','vote_average','vote_count']]

# %%
df
# Out:
#         id                                          title release_date  \
# 0      238                                  The Godfather   1972-03-14
# 1      278                       The Shawshank Redemption   1994-09-23
# 2      240                          The Godfather Part II   1974-12-20
# 3    19404                    Dilwale Dulhania Le Jayenge   1995-10-19
# 4      424                               Schindler's List   1993-12-15
# 5   667257                              Impossible Things   2021-06-17
# 6      129                                  Spirited Away   2001-07-20
# 7   372058                                     Your Name.   2016-08-26
# 8      389                                   12 Angry Men   1957-04-10
# 9   496243                                       Parasite   2019-05-30
# 10  724089                     Gabriel's Inferno: Part II   2020-07-31
# 11  696374                              Gabriel's Inferno   2020-05-29
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,516):
   
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=61e0011ba95dcb6e15587b2ebe4fd456&language=en-US&page={}'.format(i))
    if (response.json()['results']):
        temp_df = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','vote_average','vote_count']]

        df = df.append(temp_df,ignore_index=True)
    else:
        pass
# Out:
# C:\Users\Nihar\AppData\Local\Temp\ipykernel_13996\363430123.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\Nihar\AppData\Local\Temp\ipykernel_13996\363430123.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\Nihar\AppData\Local\Temp\ipykernel_13996\363430123.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\Nihar\AppData\Local\Temp\ipykernel_13996\363430123.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# ...

# %%
df
# Out:
#            id                        title release_date  \
# 0         238                The Godfather   1972-03-14
# 1         278     The Shawshank Redemption   1994-09-23
# 2         240        The Godfather Part II   1974-12-20
# 3       19404  Dilwale Dulhania Le Jayenge   1995-10-19
# 4         424             Schindler's List   1993-12-15
# ...       ...                          ...          ...
# 19995   65055               Shark Night 3D   2011-09-02
# 19996   11859                    Fair Game   1995-11-03
# 19997  269173                  The Anomaly   2014-06-19
# 19998  590706                    Jiu Jitsu   2020-11-20
# 19999   78381                        Twixt   2011-09-10
#
#                                                 overview  vote_average  \
# 0      Spanning the years 1945 to 1955, a chronicle o...           8.7
# 1      Framed in the 1940s for the double murder of h...           8.7
# 2      In the continuing saga of the Corleone crime f...           8.6
# ...

# %%
df.shape
# Out:
# (20000, 6)

# %%
df.to_csv('movies.csv')

# %% [markdown]
# fetech differnt datasets : https://rapidapi.com/collection/list-of-free-apis
